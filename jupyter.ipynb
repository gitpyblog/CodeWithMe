# %%
9 % 2  # Zwraca 1 dla liczb nieparzystych
# Out:
# 1

# %%
10 % 2  # Zwraca 1 dla liczb # parzystych
# Out:
# 0

# %%
9 // 2  # Zwraca całości w dzielnej
# Out:
# 4

# %%
import string
string.punctuation  # znaki interpunkcyjne
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
